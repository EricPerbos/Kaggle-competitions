# %%
"""
This is an upgraded version of Ceshine's and Linzhi and Andy Harless starter script, simply adding more
average features and weekly average features on it.
"""
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.advanced_activations import PReLU
from keras.layers.normalization import BatchNormalization
from keras.layers import LSTM
from keras import callbacks
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import gc
# Out:
# Using TensorFlow backend.
# /home/eric/anaconda3/envs/deep-learning/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
PATH = 'data/favorita/'
# !ls {PATH}
# Out:
# 1stplace_nn_sub_100e.csv  raw_test
# 1stplace_nn_sub_10e.csv   sample_submission.csv
# holidays_events.csv	  stores.csv
# items.csv		  test.csv
# march2017-v1.csv.gz	  tmp
# march2017-v5.csv.gz	  train.csv
# march2017-v6.csv.gz	  transactions.csv
# march2017-v7.csv.gz	  winning_with_sample_weight.csv
# models			  winning_with_sample_weight.csv.gz
# oil.csv

# %%
df_train = pd.read_csv(
    f'{PATH}train.csv', usecols=[1, 2, 3, 4, 5],
    dtype={'onpromotion': bool},
    converters={'unit_sales': lambda u: np.log1p(
        float(u)) if float(u) > 0 else 0},
    parse_dates=["date"],
    skiprows=range(1, 101688779)  # skip entries up to 2016-12-31
)

# %%
df_train.head()
# Out:
#         date  store_nbr  item_nbr  unit_sales  onpromotion
# 0 2016-12-31         54   2048674    0.693147        False
# 1 2017-01-01         25     99197    0.693147        False
# 2 2017-01-01         25    103665    2.079442        False
# 3 2017-01-01         25    105574    0.693147        False
# 4 2017-01-01         25    105857    1.609438        False

# %%
df_train.shape
# Out:
# (23808262, 5)

# %%
df_test = pd.read_csv(
    f'{PATH}test.csv', usecols=[0, 1, 2, 3, 4],
    dtype={'onpromotion': bool},
    parse_dates=["date"]  # , date_parser=parser
).set_index(
    ['store_nbr', 'item_nbr', 'date']
)

# %%
df_test.head()
# Out:
#                                       id  onpromotion
# store_nbr item_nbr date
# 1         96995    2017-08-16  125497040        False
#           99197    2017-08-16  125497041        False
#           103501   2017-08-16  125497042        False
#           103520   2017-08-16  125497043        False
#           103665   2017-08-16  125497044        False

# %%
items = pd.read_csv(
    f'{PATH}items.csv',
).set_index("item_nbr")

# %%
items.head()
# Out:
#                 family  class  perishable
# item_nbr
# 96995        GROCERY I   1093           0
# 99197        GROCERY I   1067           0
# 103501        CLEANING   3008           0
# 103520       GROCERY I   1028           0
# 103665    BREAD/BAKERY   2712           1

# %%
stores = pd.read_csv(
    f'{PATH}stores.csv',
).set_index("store_nbr")

# %%
stores.head()
# Out:
#                     city                           state type  cluster
# store_nbr
# 1                  Quito                       Pichincha    D       13
# 2                  Quito                       Pichincha    D       13
# 3                  Quito                       Pichincha    D        8
# 4                  Quito                       Pichincha    D        9
# 5          Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
le = LabelEncoder()
items['family'] = le.fit_transform(items['family'].values)

stores['city'] = le.fit_transform(stores['city'].values)
stores['state'] = le.fit_transform(stores['state'].values)
stores['type'] = le.fit_transform(stores['type'].values)

# %%
df_2017 = df_train.loc[df_train.date>=pd.datetime(2017,1,1)]
del df_train

# %%
df_2017.shape
# Out:
# (23808261, 5)

# %%
df_2017.head()
# Out:
#         date  store_nbr  item_nbr  unit_sales  onpromotion
# 1 2017-01-01         25     99197    0.693147        False
# 2 2017-01-01         25    103665    2.079442        False
# 3 2017-01-01         25    105574    0.693147        False
# 4 2017-01-01         25    105857    1.609438        False
# 5 2017-01-01         25    106716    1.098612        False

# %%
promo_2017_train = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack(
        level=-1).fillna(False)
promo_2017_train.columns = promo_2017_train.columns.get_level_values(1)
promo_2017_test = df_test[["onpromotion"]].unstack(level=-1).fillna(False)
promo_2017_test.columns = promo_2017_test.columns.get_level_values(1)
promo_2017_test = promo_2017_test.reindex(promo_2017_train.index).fillna(False)
promo_2017 = pd.concat([promo_2017_train, promo_2017_test], axis=1)
del promo_2017_test, promo_2017_train

# %%
df_2017 = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["unit_sales"]].unstack(
        level=-1).fillna(0)
df_2017.columns = df_2017.columns.get_level_values(1)

# %%
items = items.reindex(df_2017.index.get_level_values(1))
stores = stores.reindex(df_2017.index.get_level_values(0))

# %%
df_2017_item = df_2017.groupby('item_nbr')[df_2017.columns].sum()
promo_2017_item = promo_2017.groupby('item_nbr')[promo_2017.columns].sum()

# %%
df_2017_store_class = df_2017.reset_index()
df_2017_store_class['class'] = items['class'].values
df_2017_store_class_index = df_2017_store_class[['class', 'store_nbr']]
df_2017_store_class = df_2017_store_class.groupby(['class', 'store_nbr'])[df_2017.columns].sum()

# %%
df_2017_promo_store_class = promo_2017.reset_index()
df_2017_promo_store_class['class'] = items['class'].values
df_2017_promo_store_class_index = df_2017_promo_store_class[['class', 'store_nbr']]
df_2017_promo_store_class = df_2017_promo_store_class.groupby(['class', 'store_nbr'])[promo_2017.columns].sum()

# %%
def get_timespan(df, dt, minus, periods, freq='D'):
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

# %%
def prepare_dataset(df, promo_df, t2017, is_train=True, name_prefix=None):
    X = {
        "promo_14_2017": get_timespan(promo_df, t2017, 14, 14).sum(axis=1).values,
        "promo_60_2017": get_timespan(promo_df, t2017, 60, 60).sum(axis=1).values,
        "promo_140_2017": get_timespan(promo_df, t2017, 140, 140).sum(axis=1).values,
        "promo_3_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 3).sum(axis=1).values,
        "promo_7_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 7).sum(axis=1).values,
        "promo_14_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 14).sum(axis=1).values,
    }

    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)
        X['diff_%s_mean' % i] = tmp.diff(axis=1).mean(axis=1).values
        X['mean_%s_decay' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values
        X['mean_%s' % i] = tmp.mean(axis=1).values
        X['median_%s' % i] = tmp.median(axis=1).values
        X['min_%s' % i] = tmp.min(axis=1).values
        X['max_%s' % i] = tmp.max(axis=1).values
        X['std_%s' % i] = tmp.std(axis=1).values

    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017 + timedelta(days=-7), i, i)
        X['diff_%s_mean_2' % i] = tmp.diff(axis=1).mean(axis=1).values
        X['mean_%s_decay_2' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values
        X['mean_%s_2' % i] = tmp.mean(axis=1).values
        X['median_%s_2' % i] = tmp.median(axis=1).values
        X['min_%s_2' % i] = tmp.min(axis=1).values
        X['max_%s_2' % i] = tmp.max(axis=1).values
        X['std_%s_2' % i] = tmp.std(axis=1).values

    for i in [7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)
        X['has_sales_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values
        X['last_has_sales_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values
        X['first_has_sales_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values

        tmp = get_timespan(promo_df, t2017, i, i)
        X['has_promo_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values
        X['last_has_promo_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values
        X['first_has_promo_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values

    tmp = get_timespan(promo_df, t2017 + timedelta(days=16), 15, 15)
    X['has_promo_days_in_after_15_days'] = (tmp > 0).sum(axis=1).values
    X['last_has_promo_day_in_after_15_days'] = i - ((tmp > 0) * np.arange(15)).max(axis=1).values
    X['first_has_promo_day_in_after_15_days'] = ((tmp > 0) * np.arange(15, 0, -1)).max(axis=1).values

    for i in range(1, 16):
        X['day_%s_2017' % i] = get_timespan(df, t2017, i, 1).values.ravel()

    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(df, t2017, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(df, t2017, 140-i, 20, freq='7D').mean(axis=1).values

    for i in range(-16, 16):
        X["promo_{}".format(i)] = promo_df[t2017 + timedelta(days=i)].values.astype(np.uint8)

    X = pd.DataFrame(X)

    if is_train:
        y = df[
            pd.date_range(t2017, periods=16)
        ].values
        return X, y
    if name_prefix is not None:
        X.columns = ['%s_%s' % (name_prefix, c) for c in X.columns]
    return X

# %%
print("Preparing dataset...")
num_days = 8
t2017 = date(2017, 5, 31)
X_l, y_l = [], []
for i in range(num_days):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(df_2017, promo_2017, t2017 + delta)

    X_tmp2 = prepare_dataset(df_2017_item, promo_2017_item, t2017 + delta, is_train=False, name_prefix='item')
    X_tmp2.index = df_2017_item.index
    X_tmp2 = X_tmp2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

    X_tmp3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, t2017 + delta, is_train=False, name_prefix='store_class')
    X_tmp3.index = df_2017_store_class.index
    X_tmp3 = X_tmp3.reindex(df_2017_store_class_index).reset_index(drop=True)

    X_tmp = pd.concat([X_tmp, X_tmp2, X_tmp3, items.reset_index(), stores.reset_index()], axis=1)

    X_l.append(X_tmp)
    y_l.append(y_tmp)

X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)

del X_l, y_l
# Out:
# Preparing dataset...

# %%
X_val, y_val = prepare_dataset(df_2017, promo_2017, date(2017, 7, 26))
X_val2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 7, 26), is_train=False, name_prefix='item')
X_val2.index = df_2017_item.index
X_val2 = X_val2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_val3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, date(2017, 7, 26), is_train=False, name_prefix='store_class')
X_val3.index = df_2017_store_class.index
X_val3 = X_val3.reindex(df_2017_store_class_index).reset_index(drop=True)

X_val = pd.concat([X_val, X_val2, X_val3, items.reset_index(), stores.reset_index()], axis=1)

X_test = prepare_dataset(df_2017, promo_2017, date(2017, 8, 16), is_train=False)
X_test2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 8, 16), is_train=False, name_prefix='item')
X_test2.index = df_2017_item.index
X_test2 = X_test2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_test3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, date(2017, 8, 16), is_train=False, name_prefix='store_class')
X_test3.index = df_2017_store_class.index
X_test3 = X_test3.reindex(df_2017_store_class_index).reset_index(drop=True)

X_test = pd.concat([X_test, X_test2, X_test3, items.reset_index(), stores.reset_index()], axis=1)
del df_2017_item, promo_2017_item, df_2017_store_class, df_2017_promo_store_class, df_2017_store_class_index
gc.collect()
# Out:
# 2420

# %%
scaler = StandardScaler()
scaler.fit(pd.concat([X_train, X_val, X_test]))
X_train[:] = scaler.transform(X_train)
X_val[:] = scaler.transform(X_val)
X_test[:] = scaler.transform(X_test)

# %%
X_train = X_train.as_matrix()
X_test = X_test.as_matrix()
X_val = X_val.as_matrix()
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))

# %%
X_train.shape
# Out:
# (1340120, 1, 561)

# %%
def build_model():
    model = Sequential()
    model.add(LSTM(512, input_shape=(X_train.shape[1],X_train.shape[2])))
    model.add(BatchNormalization())
    model.add(Dropout(.2))

    model.add(Dense(256))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.1))

    model.add(Dense(256))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.1))

    model.add(Dense(128))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.05))

    model.add(Dense(64))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.05))

    model.add(Dense(32))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.05))

    model.add(Dense(16))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.05))

    model.add(Dense(1))

    return model

# %%
N_EPOCHS = 15

# %%
val_pred = []
test_pred = []
# wtpath = 'weights.hdf5'  # To save best epoch. But need Keras bug to be fixed first.
sample_weights=np.array( pd.concat([items["perishable"]] * num_days) * 0.25 + 1 )
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    y = y_train[:, i]
    y_mean = y.mean()
    xv = X_val
    yv = y_val[:, i]
    model = build_model()
    opt = optimizers.Adam(lr=0.001)
    model.compile(loss='mse', optimizer=opt, metrics=['mse'])

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')
        ]
    model.fit(X_train, y - y_mean, batch_size = 65536, epochs = N_EPOCHS, verbose=2,
               sample_weight=sample_weights, validation_data=(xv,yv-y_mean), callbacks=callbacks )
    val_pred.append(model.predict(X_val)+y_mean)
    test_pred.append(model.predict(X_test)+y_mean)
# Out:
# ==================================================
# Step 1
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 44s - loss: 0.9239 - mean_squared_error: 0.8708 - val_loss: 2.3893 - val_mean_squared_error: 2.3893
# Epoch 2/15
#  - 42s - loss: 0.5161 - mean_squared_error: 0.4866 - val_loss: 1.1362 - val_mean_squared_error: 1.1362
# Epoch 3/15
#  - 42s - loss: 0.4799 - mean_squared_error: 0.4530 - val_loss: 0.6137 - val_mean_squared_error: 0.6137
# Epoch 4/15
#  - 42s - loss: 0.4587 - mean_squared_error: 0.4334 - val_loss: 0.4411 - val_mean_squared_error: 0.4411
# Epoch 5/15
#  - 41s - loss: 0.4399 - mean_squared_error: 0.4162 - val_loss: 0.3632 - val_mean_squared_error: 0.3632
# Epoch 6/15
#  - 41s - loss: 0.4236 - mean_squared_error: 0.4013 - val_loss: 0.3387 - val_mean_squared_error: 0.3387
# Epoch 7/15
#  - 42s - loss: 0.4103 - mean_squared_error: 0.3892 - val_loss: 0.3244 - val_mean_squared_error: 0.3244
# Epoch 8/15
#  - 43s - loss: 0.4001 - mean_squared_error: 0.3798 - val_loss: 0.3147 - val_mean_squared_error: 0.3147
# Epoch 9/15
#  - 43s - loss: 0.3919 - mean_squared_error: 0.3722 - val_loss: 0.3139 - val_mean_squared_error: 0.3139
# Epoch 10/15
#  - 42s - loss: 0.3846 - mean_squared_error: 0.3655 - val_loss: 0.3083 - val_mean_squared_error: 0.3083
# Epoch 11/15
#  - 42s - loss: 0.3789 - mean_squared_error: 0.3600 - val_loss: 0.3020 - val_mean_squared_error: 0.3020
# Epoch 12/15
#  - 42s - loss: 0.3737 - mean_squared_error: 0.3552 - val_loss: 0.3013 - val_mean_squared_error: 0.3013
# Epoch 13/15
#  - 42s - loss: 0.3692 - mean_squared_error: 0.3510 - val_loss: 0.2984 - val_mean_squared_error: 0.2984
# Epoch 14/15
#  - 42s - loss: 0.3649 - mean_squared_error: 0.3469 - val_loss: 0.2941 - val_mean_squared_error: 0.2941
# Epoch 15/15
#  - 42s - loss: 0.3605 - mean_squared_error: 0.3428 - val_loss: 0.2923 - val_mean_squared_error: 0.2923
# ==================================================
# Step 2
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 43s - loss: 0.9296 - mean_squared_error: 0.8793 - val_loss: 1.3364 - val_mean_squared_error: 1.3364
# Epoch 2/15
#  - 43s - loss: 0.5400 - mean_squared_error: 0.5114 - val_loss: 0.7621 - val_mean_squared_error: 0.7621
# Epoch 3/15
#  - 43s - loss: 0.5084 - mean_squared_error: 0.4817 - val_loss: 0.4906 - val_mean_squared_error: 0.4906
# Epoch 4/15
#  - 42s - loss: 0.4894 - mean_squared_error: 0.4639 - val_loss: 0.4046 - val_mean_squared_error: 0.4046
# Epoch 5/15
#  - 42s - loss: 0.4751 - mean_squared_error: 0.4503 - val_loss: 0.3740 - val_mean_squared_error: 0.3740
# Epoch 6/15
#  - 43s - loss: 0.4614 - mean_squared_error: 0.4374 - val_loss: 0.3596 - val_mean_squared_error: 0.3596
# Epoch 7/15
#  - 42s - loss: 0.4520 - mean_squared_error: 0.4285 - val_loss: 0.3483 - val_mean_squared_error: 0.3483
# Epoch 8/15
#  - 42s - loss: 0.4432 - mean_squared_error: 0.4203 - val_loss: 0.3410 - val_mean_squared_error: 0.3410
# Epoch 9/15
#  - 42s - loss: 0.4338 - mean_squared_error: 0.4112 - val_loss: 0.3375 - val_mean_squared_error: 0.3375
# Epoch 10/15
#  - 42s - loss: 0.4267 - mean_squared_error: 0.4046 - val_loss: 0.3304 - val_mean_squared_error: 0.3304
# Epoch 11/15
#  - 41s - loss: 0.4203 - mean_squared_error: 0.3986 - val_loss: 0.3272 - val_mean_squared_error: 0.3272
# Epoch 12/15
#  - 42s - loss: 0.4140 - mean_squared_error: 0.3926 - val_loss: 0.3269 - val_mean_squared_error: 0.3269
# Epoch 13/15
#  - 42s - loss: 0.4091 - mean_squared_error: 0.3879 - val_loss: 0.3266 - val_mean_squared_error: 0.3266
# Epoch 14/15
#  - 41s - loss: 0.4039 - mean_squared_error: 0.3830 - val_loss: 0.3215 - val_mean_squared_error: 0.3215
# Epoch 15/15
#  - 41s - loss: 0.3990 - mean_squared_error: 0.3783 - val_loss: 0.3179 - val_mean_squared_error: 0.3179
# ==================================================
# Step 3
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 44s - loss: 1.0648 - mean_squared_error: 1.0066 - val_loss: 1.4970 - val_mean_squared_error: 1.4970
# Epoch 2/15
#  - 42s - loss: 0.5700 - mean_squared_error: 0.5406 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 3/15
#  - 42s - loss: 0.5291 - mean_squared_error: 0.5022 - val_loss: 0.4896 - val_mean_squared_error: 0.4896
# Epoch 4/15
#  - 42s - loss: 0.5062 - mean_squared_error: 0.4807 - val_loss: 0.4043 - val_mean_squared_error: 0.4043
# Epoch 5/15
#  - 41s - loss: 0.4866 - mean_squared_error: 0.4623 - val_loss: 0.3797 - val_mean_squared_error: 0.3797
# Epoch 6/15
#  - 41s - loss: 0.4708 - mean_squared_error: 0.4476 - val_loss: 0.3627 - val_mean_squared_error: 0.3627
# Epoch 7/15
#  - 41s - loss: 0.4583 - mean_squared_error: 0.4360 - val_loss: 0.3527 - val_mean_squared_error: 0.3527
# Epoch 8/15
#  - 41s - loss: 0.4482 - mean_squared_error: 0.4264 - val_loss: 0.3516 - val_mean_squared_error: 0.3516
# Epoch 9/15
#  - 42s - loss: 0.4384 - mean_squared_error: 0.4172 - val_loss: 0.3423 - val_mean_squared_error: 0.3423
# Epoch 10/15
#  - 42s - loss: 0.4322 - mean_squared_error: 0.4113 - val_loss: 0.3408 - val_mean_squared_error: 0.3408
# Epoch 11/15
#  - 42s - loss: 0.4245 - mean_squared_error: 0.4040 - val_loss: 0.3400 - val_mean_squared_error: 0.3400
# Epoch 12/15
#  - 42s - loss: 0.4190 - mean_squared_error: 0.3988 - val_loss: 0.3345 - val_mean_squared_error: 0.3345
# Epoch 13/15
#  - 42s - loss: 0.4134 - mean_squared_error: 0.3934 - val_loss: 0.3334 - val_mean_squared_error: 0.3334
# Epoch 14/15
#  - 42s - loss: 0.4079 - mean_squared_error: 0.3882 - val_loss: 0.3322 - val_mean_squared_error: 0.3322
# Epoch 15/15
#  - 43s - loss: 0.4035 - mean_squared_error: 0.3840 - val_loss: 0.3315 - val_mean_squared_error: 0.3315
# ==================================================
# Step 4
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 44s - loss: 0.8547 - mean_squared_error: 0.8090 - val_loss: 1.5362 - val_mean_squared_error: 1.5362
# Epoch 2/15
#  - 42s - loss: 0.5247 - mean_squared_error: 0.4974 - val_loss: 0.8671 - val_mean_squared_error: 0.8671
# Epoch 3/15
#  - 42s - loss: 0.4900 - mean_squared_error: 0.4644 - val_loss: 0.5206 - val_mean_squared_error: 0.5206
# Epoch 4/15
#  - 42s - loss: 0.4719 - mean_squared_error: 0.4474 - val_loss: 0.4186 - val_mean_squared_error: 0.4186
# Epoch 5/15
#  - 43s - loss: 0.4583 - mean_squared_error: 0.4344 - val_loss: 0.3856 - val_mean_squared_error: 0.3856
# Epoch 6/15
#  - 41s - loss: 0.4467 - mean_squared_error: 0.4236 - val_loss: 0.3690 - val_mean_squared_error: 0.3690
# Epoch 7/15
#  - 42s - loss: 0.4369 - mean_squared_error: 0.4142 - val_loss: 0.3601 - val_mean_squared_error: 0.3601
# Epoch 8/15
#  - 42s - loss: 0.4284 - mean_squared_error: 0.4061 - val_loss: 0.3586 - val_mean_squared_error: 0.3586
# Epoch 9/15
#  - 42s - loss: 0.4224 - mean_squared_error: 0.4005 - val_loss: 0.3543 - val_mean_squared_error: 0.3543
# Epoch 10/15
#  - 42s - loss: 0.4163 - mean_squared_error: 0.3946 - val_loss: 0.3521 - val_mean_squared_error: 0.3521
# Epoch 11/15
#  - 42s - loss: 0.4111 - mean_squared_error: 0.3896 - val_loss: 0.3490 - val_mean_squared_error: 0.3490
# Epoch 12/15
#  - 41s - loss: 0.4063 - mean_squared_error: 0.3852 - val_loss: 0.3522 - val_mean_squared_error: 0.3522
# Epoch 13/15
#  - 42s - loss: 0.4015 - mean_squared_error: 0.3804 - val_loss: 0.3474 - val_mean_squared_error: 0.3474
# Epoch 14/15
#  - 43s - loss: 0.3983 - mean_squared_error: 0.3774 - val_loss: 0.3469 - val_mean_squared_error: 0.3469
# Epoch 15/15
#  - 42s - loss: 0.3947 - mean_squared_error: 0.3740 - val_loss: 0.3473 - val_mean_squared_error: 0.3473
# ==================================================
# Step 5
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 45s - loss: 1.0868 - mean_squared_error: 1.0341 - val_loss: 1.5796 - val_mean_squared_error: 1.5796
# Epoch 2/15
#  - 42s - loss: 0.6052 - mean_squared_error: 0.5746 - val_loss: 0.8898 - val_mean_squared_error: 0.8898
# Epoch 3/15
#  - 42s - loss: 0.5617 - mean_squared_error: 0.5334 - val_loss: 0.5592 - val_mean_squared_error: 0.5592
# Epoch 4/15
#  - 41s - loss: 0.5385 - mean_squared_error: 0.5114 - val_loss: 0.4553 - val_mean_squared_error: 0.4553
# Epoch 5/15
#  - 42s - loss: 0.5197 - mean_squared_error: 0.4936 - val_loss: 0.4048 - val_mean_squared_error: 0.4048
# Epoch 6/15
#  - 43s - loss: 0.5052 - mean_squared_error: 0.4800 - val_loss: 0.3873 - val_mean_squared_error: 0.3873
# Epoch 7/15
#  - 43s - loss: 0.4936 - mean_squared_error: 0.4691 - val_loss: 0.3740 - val_mean_squared_error: 0.3740
# Epoch 8/15
#  - 42s - loss: 0.4811 - mean_squared_error: 0.4573 - val_loss: 0.3691 - val_mean_squared_error: 0.3691
# Epoch 9/15
#  - 42s - loss: 0.4719 - mean_squared_error: 0.4485 - val_loss: 0.3648 - val_mean_squared_error: 0.3648
# Epoch 10/15
#  - 42s - loss: 0.4626 - mean_squared_error: 0.4397 - val_loss: 0.3642 - val_mean_squared_error: 0.3642
# Epoch 11/15
#  - 42s - loss: 0.4555 - mean_squared_error: 0.4328 - val_loss: 0.3573 - val_mean_squared_error: 0.3573
# Epoch 12/15
#  - 43s - loss: 0.4481 - mean_squared_error: 0.4258 - val_loss: 0.3548 - val_mean_squared_error: 0.3548
# Epoch 13/15
#  - 43s - loss: 0.4425 - mean_squared_error: 0.4205 - val_loss: 0.3552 - val_mean_squared_error: 0.3552
# Epoch 14/15
#  - 42s - loss: 0.4366 - mean_squared_error: 0.4149 - val_loss: 0.3497 - val_mean_squared_error: 0.3497
# Epoch 15/15
#  - 42s - loss: 0.4311 - mean_squared_error: 0.4096 - val_loss: 0.3485 - val_mean_squared_error: 0.3485
# ==================================================
# Step 6
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 46s - loss: 0.9714 - mean_squared_error: 0.9191 - val_loss: 0.8353 - val_mean_squared_error: 0.8353
# Epoch 2/15
#  - 42s - loss: 0.5682 - mean_squared_error: 0.5379 - val_loss: 0.5628 - val_mean_squared_error: 0.5628
# Epoch 3/15
#  - 41s - loss: 0.5346 - mean_squared_error: 0.5063 - val_loss: 0.4425 - val_mean_squared_error: 0.4425
# Epoch 4/15
#  - 42s - loss: 0.5144 - mean_squared_error: 0.4873 - val_loss: 0.4028 - val_mean_squared_error: 0.4028
# Epoch 5/15
#  - 43s - loss: 0.4994 - mean_squared_error: 0.4729 - val_loss: 0.3834 - val_mean_squared_error: 0.3834
# Epoch 6/15
#  - 42s - loss: 0.4859 - mean_squared_error: 0.4603 - val_loss: 0.3733 - val_mean_squared_error: 0.3733
# Epoch 7/15
#  - 42s - loss: 0.4756 - mean_squared_error: 0.4504 - val_loss: 0.3676 - val_mean_squared_error: 0.3676
# Epoch 8/15
#  - 43s - loss: 0.4660 - mean_squared_error: 0.4413 - val_loss: 0.3628 - val_mean_squared_error: 0.3628
# Epoch 9/15
#  - 43s - loss: 0.4589 - mean_squared_error: 0.4346 - val_loss: 0.3604 - val_mean_squared_error: 0.3604
# Epoch 10/15
#  - 43s - loss: 0.4524 - mean_squared_error: 0.4284 - val_loss: 0.3588 - val_mean_squared_error: 0.3588
# Epoch 11/15
#  - 42s - loss: 0.4456 - mean_squared_error: 0.4219 - val_loss: 0.3535 - val_mean_squared_error: 0.3535
# Epoch 12/15
#  - 43s - loss: 0.4399 - mean_squared_error: 0.4164 - val_loss: 0.3536 - val_mean_squared_error: 0.3536
# Epoch 13/15
#  - 41s - loss: 0.4349 - mean_squared_error: 0.4117 - val_loss: 0.3509 - val_mean_squared_error: 0.3509
# Epoch 14/15
#  - 41s - loss: 0.4311 - mean_squared_error: 0.4081 - val_loss: 0.3494 - val_mean_squared_error: 0.3494
# Epoch 15/15
#  - 41s - loss: 0.4254 - mean_squared_error: 0.4027 - val_loss: 0.3491 - val_mean_squared_error: 0.3491
# ==================================================
# Step 7
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 45s - loss: 1.0839 - mean_squared_error: 1.0270 - val_loss: 1.1360 - val_mean_squared_error: 1.1360
# Epoch 2/15
#  - 42s - loss: 0.5938 - mean_squared_error: 0.5628 - val_loss: 0.6621 - val_mean_squared_error: 0.6621
# Epoch 3/15
#  - 42s - loss: 0.5549 - mean_squared_error: 0.5261 - val_loss: 0.4923 - val_mean_squared_error: 0.4923
# Epoch 4/15
#  - 41s - loss: 0.5326 - mean_squared_error: 0.5052 - val_loss: 0.4426 - val_mean_squared_error: 0.4426
# Epoch 5/15
#  - 42s - loss: 0.5141 - mean_squared_error: 0.4878 - val_loss: 0.4226 - val_mean_squared_error: 0.4226
# Epoch 6/15
#  - 42s - loss: 0.4981 - mean_squared_error: 0.4729 - val_loss: 0.4129 - val_mean_squared_error: 0.4129
# Epoch 7/15
#  - 43s - loss: 0.4839 - mean_squared_error: 0.4595 - val_loss: 0.4115 - val_mean_squared_error: 0.4115
# Epoch 8/15
#  - 44s - loss: 0.4741 - mean_squared_error: 0.4504 - val_loss: 0.4073 - val_mean_squared_error: 0.4073
# Epoch 9/15
#  - 44s - loss: 0.4640 - mean_squared_error: 0.4408 - val_loss: 0.4043 - val_mean_squared_error: 0.4043
# Epoch 10/15
#  - 43s - loss: 0.4561 - mean_squared_error: 0.4334 - val_loss: 0.4017 - val_mean_squared_error: 0.4017
# Epoch 11/15
#  - 44s - loss: 0.4487 - mean_squared_error: 0.4263 - val_loss: 0.3991 - val_mean_squared_error: 0.3991
# Epoch 12/15
#  - 43s - loss: 0.4423 - mean_squared_error: 0.4202 - val_loss: 0.3978 - val_mean_squared_error: 0.3978
# Epoch 13/15
#  - 42s - loss: 0.4356 - mean_squared_error: 0.4139 - val_loss: 0.3975 - val_mean_squared_error: 0.3975
# Epoch 14/15
#  - 42s - loss: 0.4312 - mean_squared_error: 0.4097 - val_loss: 0.3949 - val_mean_squared_error: 0.3949
# Epoch 15/15
#  - 42s - loss: 0.4264 - mean_squared_error: 0.4051 - val_loss: 0.3925 - val_mean_squared_error: 0.3925
# ==================================================
# Step 8
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 47s - loss: 0.8607 - mean_squared_error: 0.8121 - val_loss: 2.5840 - val_mean_squared_error: 2.5840
# Epoch 2/15
#  - 43s - loss: 0.5228 - mean_squared_error: 0.4929 - val_loss: 0.8718 - val_mean_squared_error: 0.8718
# Epoch 3/15
#  - 43s - loss: 0.4921 - mean_squared_error: 0.4646 - val_loss: 0.4995 - val_mean_squared_error: 0.4995
# Epoch 4/15
#  - 42s - loss: 0.4705 - mean_squared_error: 0.4450 - val_loss: 0.4178 - val_mean_squared_error: 0.4178
# Epoch 5/15
#  - 43s - loss: 0.4526 - mean_squared_error: 0.4286 - val_loss: 0.3985 - val_mean_squared_error: 0.3985
# Epoch 6/15
#  - 43s - loss: 0.4383 - mean_squared_error: 0.4156 - val_loss: 0.3863 - val_mean_squared_error: 0.3863
# Epoch 7/15
#  - 44s - loss: 0.4279 - mean_squared_error: 0.4060 - val_loss: 0.3794 - val_mean_squared_error: 0.3794
# Epoch 8/15
#  - 43s - loss: 0.4201 - mean_squared_error: 0.3989 - val_loss: 0.3716 - val_mean_squared_error: 0.3716
# Epoch 9/15
#  - 43s - loss: 0.4138 - mean_squared_error: 0.3931 - val_loss: 0.3698 - val_mean_squared_error: 0.3698
# Epoch 10/15
#  - 44s - loss: 0.4067 - mean_squared_error: 0.3865 - val_loss: 0.3679 - val_mean_squared_error: 0.3679
# Epoch 11/15
#  - 42s - loss: 0.4013 - mean_squared_error: 0.3814 - val_loss: 0.3652 - val_mean_squared_error: 0.3652
# Epoch 12/15
#  - 41s - loss: 0.3970 - mean_squared_error: 0.3775 - val_loss: 0.3631 - val_mean_squared_error: 0.3631
# Epoch 13/15
#  - 42s - loss: 0.3927 - mean_squared_error: 0.3735 - val_loss: 0.3611 - val_mean_squared_error: 0.3611
# Epoch 14/15
#  - 43s - loss: 0.3884 - mean_squared_error: 0.3694 - val_loss: 0.3602 - val_mean_squared_error: 0.3602
# Epoch 15/15
#  - 43s - loss: 0.3845 - mean_squared_error: 0.3658 - val_loss: 0.3600 - val_mean_squared_error: 0.3600
# ==================================================
# Step 9
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 46s - loss: 0.9027 - mean_squared_error: 0.8546 - val_loss: 1.2034 - val_mean_squared_error: 1.2034
# Epoch 2/15
#  - 42s - loss: 0.5142 - mean_squared_error: 0.4866 - val_loss: 0.6201 - val_mean_squared_error: 0.6201
# Epoch 3/15
#  - 43s - loss: 0.4834 - mean_squared_error: 0.4575 - val_loss: 0.4642 - val_mean_squared_error: 0.4642
# Epoch 4/15
#  - 42s - loss: 0.4658 - mean_squared_error: 0.4408 - val_loss: 0.4155 - val_mean_squared_error: 0.4155
# Epoch 5/15
#  - 42s - loss: 0.4532 - mean_squared_error: 0.4288 - val_loss: 0.3987 - val_mean_squared_error: 0.3987
# Epoch 6/15
#  - 44s - loss: 0.4421 - mean_squared_error: 0.4184 - val_loss: 0.3869 - val_mean_squared_error: 0.3869
# Epoch 7/15
#  - 43s - loss: 0.4331 - mean_squared_error: 0.4100 - val_loss: 0.3798 - val_mean_squared_error: 0.3798
# Epoch 8/15
#  - 45s - loss: 0.4262 - mean_squared_error: 0.4034 - val_loss: 0.3741 - val_mean_squared_error: 0.3741
# Epoch 9/15
#  - 43s - loss: 0.4207 - mean_squared_error: 0.3982 - val_loss: 0.3721 - val_mean_squared_error: 0.3721
# Epoch 10/15
#  - 42s - loss: 0.4160 - mean_squared_error: 0.3938 - val_loss: 0.3685 - val_mean_squared_error: 0.3685
# Epoch 11/15
#  - 44s - loss: 0.4111 - mean_squared_error: 0.3891 - val_loss: 0.3655 - val_mean_squared_error: 0.3655
# Epoch 12/15
#  - 43s - loss: 0.4067 - mean_squared_error: 0.3850 - val_loss: 0.3639 - val_mean_squared_error: 0.3639
# Epoch 13/15
#  - 42s - loss: 0.4029 - mean_squared_error: 0.3814 - val_loss: 0.3628 - val_mean_squared_error: 0.3628
# Epoch 14/15
#  - 43s - loss: 0.3993 - mean_squared_error: 0.3780 - val_loss: 0.3623 - val_mean_squared_error: 0.3623
# Epoch 15/15
#  - 43s - loss: 0.3958 - mean_squared_error: 0.3747 - val_loss: 0.3628 - val_mean_squared_error: 0.3628
# ==================================================
# Step 10
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 45s - loss: 0.9632 - mean_squared_error: 0.9029 - val_loss: 1.7811 - val_mean_squared_error: 1.7811
# Epoch 2/15
#  - 42s - loss: 0.5778 - mean_squared_error: 0.5425 - val_loss: 0.8779 - val_mean_squared_error: 0.8779
# Epoch 3/15
#  - 42s - loss: 0.5406 - mean_squared_error: 0.5083 - val_loss: 0.5285 - val_mean_squared_error: 0.5285
# Epoch 4/15
#  - 42s - loss: 0.5188 - mean_squared_error: 0.4885 - val_loss: 0.4263 - val_mean_squared_error: 0.4263
# Epoch 5/15
#  - 41s - loss: 0.5006 - mean_squared_error: 0.4718 - val_loss: 0.3934 - val_mean_squared_error: 0.3934
# Epoch 6/15
#  - 42s - loss: 0.4822 - mean_squared_error: 0.4551 - val_loss: 0.3768 - val_mean_squared_error: 0.3768
# Epoch 7/15
#  - 42s - loss: 0.4688 - mean_squared_error: 0.4429 - val_loss: 0.3696 - val_mean_squared_error: 0.3696
# Epoch 8/15
#  - 41s - loss: 0.4580 - mean_squared_error: 0.4331 - val_loss: 0.3658 - val_mean_squared_error: 0.3658
# Epoch 9/15
#  - 43s - loss: 0.4490 - mean_squared_error: 0.4249 - val_loss: 0.3635 - val_mean_squared_error: 0.3635
# Epoch 10/15
#  - 42s - loss: 0.4414 - mean_squared_error: 0.4178 - val_loss: 0.3618 - val_mean_squared_error: 0.3618
# Epoch 11/15
#  - 42s - loss: 0.4333 - mean_squared_error: 0.4105 - val_loss: 0.3605 - val_mean_squared_error: 0.3605
# Epoch 12/15
#  - 42s - loss: 0.4281 - mean_squared_error: 0.4057 - val_loss: 0.3566 - val_mean_squared_error: 0.3566
# Epoch 13/15
#  - 42s - loss: 0.4217 - mean_squared_error: 0.3997 - val_loss: 0.3583 - val_mean_squared_error: 0.3583
# Epoch 14/15
#  - 43s - loss: 0.4161 - mean_squared_error: 0.3945 - val_loss: 0.3576 - val_mean_squared_error: 0.3576
# Epoch 15/15
#  - 44s - loss: 0.4120 - mean_squared_error: 0.3907 - val_loss: 0.3563 - val_mean_squared_error: 0.3563
# ==================================================
# Step 11
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 46s - loss: 1.1505 - mean_squared_error: 1.0897 - val_loss: 1.1056 - val_mean_squared_error: 1.1056
# Epoch 2/15
#  - 43s - loss: 0.6441 - mean_squared_error: 0.6112 - val_loss: 0.6044 - val_mean_squared_error: 0.6044
# Epoch 3/15
#  - 42s - loss: 0.5986 - mean_squared_error: 0.5680 - val_loss: 0.4615 - val_mean_squared_error: 0.4615
# Epoch 4/15
#  - 43s - loss: 0.5723 - mean_squared_error: 0.5430 - val_loss: 0.4188 - val_mean_squared_error: 0.4188
# Epoch 5/15
#  - 43s - loss: 0.5532 - mean_squared_error: 0.5249 - val_loss: 0.3963 - val_mean_squared_error: 0.3963
# Epoch 6/15
#  - 42s - loss: 0.5355 - mean_squared_error: 0.5083 - val_loss: 0.3863 - val_mean_squared_error: 0.3863
# Epoch 7/15
#  - 42s - loss: 0.5229 - mean_squared_error: 0.4963 - val_loss: 0.3817 - val_mean_squared_error: 0.3817
# Epoch 8/15
#  - 42s - loss: 0.5094 - mean_squared_error: 0.4836 - val_loss: 0.3780 - val_mean_squared_error: 0.3780
# Epoch 9/15
#  - 42s - loss: 0.5002 - mean_squared_error: 0.4747 - val_loss: 0.3748 - val_mean_squared_error: 0.3748
# Epoch 10/15
#  - 43s - loss: 0.4900 - mean_squared_error: 0.4651 - val_loss: 0.3720 - val_mean_squared_error: 0.3720
# Epoch 11/15
#  - 44s - loss: 0.4825 - mean_squared_error: 0.4580 - val_loss: 0.3711 - val_mean_squared_error: 0.3711
# Epoch 12/15
#  - 42s - loss: 0.4744 - mean_squared_error: 0.4503 - val_loss: 0.3692 - val_mean_squared_error: 0.3692
# Epoch 13/15
#  - 44s - loss: 0.4669 - mean_squared_error: 0.4433 - val_loss: 0.3675 - val_mean_squared_error: 0.3675
# Epoch 14/15
#  - 44s - loss: 0.4611 - mean_squared_error: 0.4378 - val_loss: 0.3672 - val_mean_squared_error: 0.3672
# Epoch 15/15
#  - 43s - loss: 0.4544 - mean_squared_error: 0.4314 - val_loss: 0.3675 - val_mean_squared_error: 0.3675
# ==================================================
# Step 12
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 46s - loss: 1.2041 - mean_squared_error: 1.1406 - val_loss: 1.8555 - val_mean_squared_error: 1.8555
# Epoch 2/15
#  - 44s - loss: 0.6545 - mean_squared_error: 0.6201 - val_loss: 0.8495 - val_mean_squared_error: 0.8495
# Epoch 3/15
#  - 43s - loss: 0.6031 - mean_squared_error: 0.5714 - val_loss: 0.5485 - val_mean_squared_error: 0.5485
# Epoch 4/15
#  - 43s - loss: 0.5757 - mean_squared_error: 0.5456 - val_loss: 0.4737 - val_mean_squared_error: 0.4737
# Epoch 5/15
#  - 43s - loss: 0.5536 - mean_squared_error: 0.5248 - val_loss: 0.4319 - val_mean_squared_error: 0.4319
# Epoch 6/15
#  - 43s - loss: 0.5367 - mean_squared_error: 0.5088 - val_loss: 0.4076 - val_mean_squared_error: 0.4076
# Epoch 7/15
#  - 42s - loss: 0.5230 - mean_squared_error: 0.4960 - val_loss: 0.3972 - val_mean_squared_error: 0.3972
# Epoch 8/15
#  - 42s - loss: 0.5103 - mean_squared_error: 0.4840 - val_loss: 0.3907 - val_mean_squared_error: 0.3907
# Epoch 9/15
#  - 43s - loss: 0.5001 - mean_squared_error: 0.4744 - val_loss: 0.3864 - val_mean_squared_error: 0.3864
# Epoch 10/15
#  - 43s - loss: 0.4910 - mean_squared_error: 0.4659 - val_loss: 0.3816 - val_mean_squared_error: 0.3816
# Epoch 11/15
#  - 43s - loss: 0.4822 - mean_squared_error: 0.4576 - val_loss: 0.3792 - val_mean_squared_error: 0.3792
# Epoch 12/15
#  - 43s - loss: 0.4746 - mean_squared_error: 0.4504 - val_loss: 0.3773 - val_mean_squared_error: 0.3773
# Epoch 13/15
#  - 44s - loss: 0.4680 - mean_squared_error: 0.4442 - val_loss: 0.3745 - val_mean_squared_error: 0.3745
# Epoch 14/15
#  - 44s - loss: 0.4624 - mean_squared_error: 0.4390 - val_loss: 0.3734 - val_mean_squared_error: 0.3734
# Epoch 15/15
#  - 43s - loss: 0.4568 - mean_squared_error: 0.4336 - val_loss: 0.3724 - val_mean_squared_error: 0.3724
# ==================================================
# Step 13
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 48s - loss: 0.9523 - mean_squared_error: 0.8947 - val_loss: 2.4135 - val_mean_squared_error: 2.4135
# Epoch 2/15
#  - 43s - loss: 0.5712 - mean_squared_error: 0.5373 - val_loss: 1.0569 - val_mean_squared_error: 1.0569
# Epoch 3/15
#  - 43s - loss: 0.5404 - mean_squared_error: 0.5089 - val_loss: 0.6277 - val_mean_squared_error: 0.6277
# Epoch 4/15
#  - 43s - loss: 0.5202 - mean_squared_error: 0.4903 - val_loss: 0.4639 - val_mean_squared_error: 0.4639
# Epoch 5/15
#  - 44s - loss: 0.5050 - mean_squared_error: 0.4762 - val_loss: 0.4209 - val_mean_squared_error: 0.4209
# Epoch 6/15
#  - 43s - loss: 0.4929 - mean_squared_error: 0.4649 - val_loss: 0.4070 - val_mean_squared_error: 0.4070
# Epoch 7/15
#  - 43s - loss: 0.4818 - mean_squared_error: 0.4547 - val_loss: 0.3933 - val_mean_squared_error: 0.3933
# Epoch 8/15
#  - 43s - loss: 0.4727 - mean_squared_error: 0.4463 - val_loss: 0.3866 - val_mean_squared_error: 0.3866
# Epoch 9/15
#  - 43s - loss: 0.4647 - mean_squared_error: 0.4389 - val_loss: 0.3799 - val_mean_squared_error: 0.3799
# Epoch 10/15
#  - 43s - loss: 0.4590 - mean_squared_error: 0.4336 - val_loss: 0.3783 - val_mean_squared_error: 0.3783
# Epoch 11/15
#  - 43s - loss: 0.4522 - mean_squared_error: 0.4272 - val_loss: 0.3723 - val_mean_squared_error: 0.3723
# Epoch 12/15
#  - 44s - loss: 0.4475 - mean_squared_error: 0.4229 - val_loss: 0.3723 - val_mean_squared_error: 0.3723
# Epoch 13/15
#  - 43s - loss: 0.4427 - mean_squared_error: 0.4184 - val_loss: 0.3707 - val_mean_squared_error: 0.3707
# Epoch 14/15
#  - 43s - loss: 0.4371 - mean_squared_error: 0.4132 - val_loss: 0.3681 - val_mean_squared_error: 0.3681
# Epoch 15/15
#  - 43s - loss: 0.4329 - mean_squared_error: 0.4092 - val_loss: 0.3691 - val_mean_squared_error: 0.3691
# ==================================================
# Step 14
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 49s - loss: 0.9392 - mean_squared_error: 0.8887 - val_loss: 1.2993 - val_mean_squared_error: 1.2993
# Epoch 2/15
#  - 43s - loss: 0.5675 - mean_squared_error: 0.5370 - val_loss: 0.7452 - val_mean_squared_error: 0.7452
# Epoch 3/15
#  - 43s - loss: 0.5365 - mean_squared_error: 0.5077 - val_loss: 0.4904 - val_mean_squared_error: 0.4904
# Epoch 4/15
#  - 44s - loss: 0.5164 - mean_squared_error: 0.4889 - val_loss: 0.4155 - val_mean_squared_error: 0.4155
# Epoch 5/15
#  - 44s - loss: 0.4995 - mean_squared_error: 0.4732 - val_loss: 0.3871 - val_mean_squared_error: 0.3871
# Epoch 6/15
#  - 44s - loss: 0.4854 - mean_squared_error: 0.4600 - val_loss: 0.3770 - val_mean_squared_error: 0.3770
# Epoch 7/15
#  - 44s - loss: 0.4737 - mean_squared_error: 0.4491 - val_loss: 0.3720 - val_mean_squared_error: 0.3720
# Epoch 8/15
#  - 43s - loss: 0.4654 - mean_squared_error: 0.4413 - val_loss: 0.3680 - val_mean_squared_error: 0.3680
# Epoch 9/15
#  - 43s - loss: 0.4583 - mean_squared_error: 0.4345 - val_loss: 0.3625 - val_mean_squared_error: 0.3625
# Epoch 10/15
#  - 43s - loss: 0.4511 - mean_squared_error: 0.4278 - val_loss: 0.3624 - val_mean_squared_error: 0.3624
# Epoch 11/15
#  - 43s - loss: 0.4448 - mean_squared_error: 0.4218 - val_loss: 0.3626 - val_mean_squared_error: 0.3626
# Epoch 12/15
#  - 44s - loss: 0.4397 - mean_squared_error: 0.4169 - val_loss: 0.3576 - val_mean_squared_error: 0.3576
# Epoch 13/15
#  - 43s - loss: 0.4343 - mean_squared_error: 0.4119 - val_loss: 0.3574 - val_mean_squared_error: 0.3574
# Epoch 14/15
#  - 43s - loss: 0.4301 - mean_squared_error: 0.4079 - val_loss: 0.3570 - val_mean_squared_error: 0.3570
# Epoch 15/15
#  - 43s - loss: 0.4255 - mean_squared_error: 0.4035 - val_loss: 0.3551 - val_mean_squared_error: 0.3551
# ==================================================
# Step 15
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 48s - loss: 0.9528 - mean_squared_error: 0.8993 - val_loss: 1.6183 - val_mean_squared_error: 1.6183
# Epoch 2/15
#  - 42s - loss: 0.5938 - mean_squared_error: 0.5617 - val_loss: 0.7150 - val_mean_squared_error: 0.7150
# Epoch 3/15
#  - 43s - loss: 0.5574 - mean_squared_error: 0.5279 - val_loss: 0.4727 - val_mean_squared_error: 0.4727
# Epoch 4/15
#  - 42s - loss: 0.5319 - mean_squared_error: 0.5045 - val_loss: 0.3980 - val_mean_squared_error: 0.3980
# Epoch 5/15
#  - 44s - loss: 0.5091 - mean_squared_error: 0.4836 - val_loss: 0.3724 - val_mean_squared_error: 0.3724
# Epoch 6/15
#  - 43s - loss: 0.4911 - mean_squared_error: 0.4673 - val_loss: 0.3629 - val_mean_squared_error: 0.3629
# Epoch 7/15
#  - 44s - loss: 0.4768 - mean_squared_error: 0.4540 - val_loss: 0.3599 - val_mean_squared_error: 0.3599
# Epoch 8/15
#  - 42s - loss: 0.4653 - mean_squared_error: 0.4434 - val_loss: 0.3536 - val_mean_squared_error: 0.3536
# Epoch 9/15
#  - 44s - loss: 0.4550 - mean_squared_error: 0.4337 - val_loss: 0.3515 - val_mean_squared_error: 0.3515
# Epoch 10/15
#  - 42s - loss: 0.4480 - mean_squared_error: 0.4271 - val_loss: 0.3497 - val_mean_squared_error: 0.3497
# Epoch 11/15
#  - 42s - loss: 0.4396 - mean_squared_error: 0.4192 - val_loss: 0.3473 - val_mean_squared_error: 0.3473
# Epoch 12/15
#  - 42s - loss: 0.4331 - mean_squared_error: 0.4129 - val_loss: 0.3471 - val_mean_squared_error: 0.3471
# Epoch 13/15
#  - 43s - loss: 0.4275 - mean_squared_error: 0.4076 - val_loss: 0.3490 - val_mean_squared_error: 0.3490
# Epoch 14/15
#  - 43s - loss: 0.4214 - mean_squared_error: 0.4018 - val_loss: 0.3445 - val_mean_squared_error: 0.3445
# Epoch 15/15
#  - 44s - loss: 0.4159 - mean_squared_error: 0.3966 - val_loss: 0.3421 - val_mean_squared_error: 0.3421
# ==================================================
# Step 16
# ==================================================
# Train on 1340120 samples, validate on 167515 samples
# Epoch 1/15
#  - 48s - loss: 0.8744 - mean_squared_error: 0.8296 - val_loss: 1.3001 - val_mean_squared_error: 1.3001
# Epoch 2/15
#  - 43s - loss: 0.5386 - mean_squared_error: 0.5107 - val_loss: 0.6648 - val_mean_squared_error: 0.6648
# Epoch 3/15
#  - 43s - loss: 0.5051 - mean_squared_error: 0.4791 - val_loss: 0.4809 - val_mean_squared_error: 0.4809
# Epoch 4/15
#  - 42s - loss: 0.4850 - mean_squared_error: 0.4599 - val_loss: 0.4327 - val_mean_squared_error: 0.4327
# Epoch 5/15
#  - 42s - loss: 0.4716 - mean_squared_error: 0.4471 - val_loss: 0.4046 - val_mean_squared_error: 0.4046
# Epoch 6/15
#  - 43s - loss: 0.4592 - mean_squared_error: 0.4353 - val_loss: 0.3922 - val_mean_squared_error: 0.3922
# Epoch 7/15
#  - 43s - loss: 0.4507 - mean_squared_error: 0.4273 - val_loss: 0.3833 - val_mean_squared_error: 0.3833
# Epoch 8/15
#  - 43s - loss: 0.4434 - mean_squared_error: 0.4203 - val_loss: 0.3768 - val_mean_squared_error: 0.3768
# Epoch 9/15
#  - 43s - loss: 0.4367 - mean_squared_error: 0.4140 - val_loss: 0.3713 - val_mean_squared_error: 0.3713
# Epoch 10/15
#  - 43s - loss: 0.4310 - mean_squared_error: 0.4086 - val_loss: 0.3718 - val_mean_squared_error: 0.3718
# Epoch 11/15
#  - 43s - loss: 0.4254 - mean_squared_error: 0.4033 - val_loss: 0.3664 - val_mean_squared_error: 0.3664
# Epoch 12/15
#  - 43s - loss: 0.4215 - mean_squared_error: 0.3996 - val_loss: 0.3654 - val_mean_squared_error: 0.3654
# Epoch 13/15
#  - 43s - loss: 0.4167 - mean_squared_error: 0.3950 - val_loss: 0.3662 - val_mean_squared_error: 0.3662
# Epoch 14/15
#  - 43s - loss: 0.4137 - mean_squared_error: 0.3921 - val_loss: 0.3669 - val_mean_squared_error: 0.3669
# Epoch 15/15
#  - 44s - loss: 0.4094 - mean_squared_error: 0.3881 - val_loss: 0.3644 - val_mean_squared_error: 0.3644

# %%
weight = items["perishable"] * 0.25 + 1
err = (y_val - np.array(val_pred).squeeze(axis=2).transpose())**2
err = err.sum(axis=1) * weight
err = np.sqrt(err.sum() / weight.sum() / 16)
print('nwrmsle = {}'.format(err))
# Out:
# nwrmsle = 0.5928160636612965

# %%
y_val = np.array(val_pred).squeeze(axis=2).transpose()
df_preds = pd.DataFrame(
    y_val, index=df_2017.index,
    columns=pd.date_range("2017-07-26", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)
df_preds["unit_sales"] = np.clip(np.expm1(df_preds["unit_sales"]), 0, 1000)
df_preds.reset_index().to_csv('nn_cv.csv', index=False)

# %%
print("Making submission...")
y_test = np.array(test_pred).squeeze(axis=2).transpose()
df_preds = pd.DataFrame(
    y_test, index=df_2017.index,
    columns=pd.date_range("2017-08-16", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)
# Out:
# Making submission...

# %%
submission = df_test[["id"]].join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv(f'{PATH}nn_sub_LSTM_15e.csv', float_format='%.4f', index=None)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 512)               2199552
# _________________________________________________________________
# batch_normalization_106 (Bat (None, 512)               2048
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_106 (Dense)            (None, 256)               131328
# _________________________________________________________________
# p_re_lu_91 (PReLU)           (None, 256)               256
# _________________________________________________________________
# batch_normalization_107 (Bat (None, 256)               1024
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_107 (Dense)            (None, 256)               65792
# _________________________________________________________________
# p_re_lu_92 (PReLU)           (None, 256)               256
# _________________________________________________________________
# batch_normalization_108 (Bat (None, 256)               1024
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 128)               32896
# _________________________________________________________________
# p_re_lu_93 (PReLU)           (None, 128)               128
# _________________________________________________________________
# batch_normalization_109 (Bat (None, 128)               512
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_109 (Dense)            (None, 64)                8256
# _________________________________________________________________
# p_re_lu_94 (PReLU)           (None, 64)                64
# _________________________________________________________________
# batch_normalization_110 (Bat (None, 64)                256
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_110 (Dense)            (None, 32)                2080
# _________________________________________________________________
# p_re_lu_95 (PReLU)           (None, 32)                32
# _________________________________________________________________
# batch_normalization_111 (Bat (None, 32)                128
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_111 (Dense)            (None, 16)                528
# _________________________________________________________________
# p_re_lu_96 (PReLU)           (None, 16)                16
# _________________________________________________________________
# batch_normalization_112 (Bat (None, 16)                64
# _________________________________________________________________
# dropout_112 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_112 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 2,446,257
# Trainable params: 2,443,729
# Non-trainable params: 2,528
# _________________________________________________________________
